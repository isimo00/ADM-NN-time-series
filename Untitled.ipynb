# %% [markdown]
# # Working code 1:

# %%
using Flux, Plots, Statistics, MLDatasets, Images, TimeSeries, CSV, DataFrames

# %% [markdown]
# Idx for covid: data.Date[2838] is last valid

# %%
data = CSV.read("BAJAJFINSV.csv", DataFrame)

# Keep only the close price, and convert the datatype to Float32, 
# Float32 is NECESSARY for recurrent models in Flux
vwap = Float32.(data.VWAP)
# Create a vector of features (our input) and a vector of labels (our target output)
X_original = vwap[1:2838]
Y = vwap[2:2839]
# Reshape input data into Flux recurrent data format
X = [[x] for x ∈ X_original]

# Model definition
model = Chain(
    RNN(1 => 32, relu),
    Dense(32 => 1, identity)
)

# Train the model
epochs = 100
opt = ADAM()
θ = Flux.params(model) # Keep track of the model parameters
for epoch ∈ 1:epochs # Training loop
    Flux.reset!(model) # Reset the hidden state of the RNN
    # Compute the gradient of the mean squared error loss
    ∇ = gradient(θ) do
        model(X[1]) # Warm-up the model
        sum(Flux.Losses.mse.([model(x)[1] for x ∈ X[2:end]], Y[2:end]))
    end
    Flux.update!(opt, θ, ∇) # Update the parameters
end

# Reshape result from Flux data format to Julia standard
Prediction = [model(x)[1] for x ∈ X]

plot(data.Date[1:2838], [X_original Prediction], label=["VWAP" "Prediction"], linewidth=3)

# %% [markdown]
# ## LSTM

# %%
data = CSV.read("BAJAJFINSV.csv", DataFrame)

output_size = 1;

# Keep only the close price, and convert the datatype to Float32, 
# Float32 is NECESSARY for recurrent models in Flux
vwap = Float32.(data.VWAP)
# Create a vector of features (our input) and a vector of labels (our target output)
X_original = vwap[1:2838]
Y = vwap[2:2839]
# Reshape input data into Flux recurrent data format
X = [[x] for x ∈ X_original]

# Model definition
model = Chain(
    RNN(1 => 32, relu),
    Dense(32 => output_size, identity)
)

# Train the model
epochs = 100
opt = ADAM()
θ = Flux.params(model) # Keep track of the model parameters
for epoch ∈ 1:epochs # Training loop
    Flux.reset!(model) # Reset the hidden state of the RNN
    # Compute the gradient of the mean squared error loss
    ∇ = gradient(θ) do
        model(X[1]) # Warm-up the model
        sum(Flux.Losses.mse.([model(x)[1] for x ∈ X[2:end]], Y[2:end]))
    end
    Flux.update!(opt, θ, ∇) # Update the parameters
end

# Reshape result from Flux data format to Julia standard
Prediction = [model(x)[1] for x ∈ X]

plot(data.Date[1:2838], [X_original Prediction], label=["VWAP" "Prediction"], linewidth=3)

# %%
# Out:
# 29-element Vector{Float32}:
#  618.37
#  659.6
#  636.41
#  670.51
#  665.87
#  602.36
#  610.65
#  628.44
#  624.95
#  653.65
#  662.71
#  614.22
#  601.0
#    ⋮
#  573.49
#  561.83
#  551.73
#  564.55
#  590.89
#  563.12
#  553.0
#  518.83
#  506.03
#  499.88
#  485.69
#  510.16

# %% [markdown]
# # Code 2

# %%
l = LSTM(3 => 5)
# Out:
# Recur(
#   LSTMCell(3 => 5),                     # 190 parameters
# )         # Total: 5 trainable arrays, 190 parameters,
#           # plus 2 non-trainable, 10 parameters, summarysize 1.062 KiB.

# %%
VWAP_o = Float32.(data.VWAP)[1:2838]
VWAP = [[x] for x ∈ VWAP_o]
Pred2 = [model(x)[1] for x ∈ VWAP]

plot(data.Date[1:2838], [VWAP_o Pred2], label=["VWAP" "Prediction"], linewidth=3)

# %%
# Flux.Losses.mse.([model(x)[1] for x ∈ X[2:end]], Y[2:end])
error = [(Flux.Losses.mse.(Pred2, VWAP_o)[i]-VWAP_o[i])/VWAP_o[i] for i in 1:2838]
plot(data.Date[20:2838], error[20:end])

# %%
a = [i for i in 1:2838]
a[0]
# Out:
# BoundsError: attempt to access 2838-element Vector{Int64} at index [0]
#
# Stacktrace:
#  [1] getindex(A::Vector{Int64}, i1::Int64)
#    @ Base ./array.jl:805
#  [2] top-level scope
#    @ In[71]:2
